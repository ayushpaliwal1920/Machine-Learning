# %% [markdown]
# # Logistic Regression : Binary Classification

# %% [markdown]
# Logistic Regression is a supervised machine learning algorithm used for classification problems. Unlike linear regression which predicts continuous values it predicts the probability that an input belongs to a specific class.

# %% [markdown]
# It is used for binary classification where the output can be one of two possible categories such as Yes/No, True/False or 0/1.
#
# It uses sigmoid function to convert inputs into a probability value between 0 and 1

# %% [markdown]
# It is used for predicting the categorical dependent variable using a given set of independent variables.

# %% [markdown]
# For logistic regression data should be linearly seperable

# %% [markdown]
# TYPES OF LOGISTIC REGRESSION :  Binomial , Multinomial , Ordinarl  read gfg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Social_Network_Ads.csv")
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# we will work inly age and purchased column

# %%
print(dataset.columns.tolist())
# Out:
# ['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased']

# %%
dataset.drop(columns=["EstimatedSalary"],inplace = True)

# %%
# our data follows the property of logistic regression :

sns.scatterplot(x="Age" , y="Purchased",data=dataset) 
plt.show()

# %% [markdown]
# Split data into dependent and independent data

# %%
x = dataset[["Age"]]
y = dataset["Purchased"]

# %% [markdown]
# train test data :

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train,_y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# accuracy analysis

# %%
lr.score(x_test,_y_test)*100
# Out:
# 91.25

# %%
lr.predict([[40]])
# Out:
# /home/ayush-paliwal/PythonEnvironments/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# Prediction line idea

# %%
sns.scatterplot(x="Age" , y="Purchased",data=dataset) 
sns.lineplot(x = "Age" , y = lr.predict(x) , data= dataset ,color = "red")
plt.show()
